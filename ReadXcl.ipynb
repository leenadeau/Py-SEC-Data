# %%
# Packages

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import full dataset 
xls=pd.ExcelFile('ex99_1.xlsx') 

# Individual tabs within excel file
msft = pd.read_excel(xls, 'MSFT') 
aapl = pd.read_excel(xls, 'AAPL')
fb = pd.read_excel(xls, 'FB')
goog = pd.read_excel(xls, 'GOOG')
nvda = pd.read_excel(xls, 'NVDA')

# %%
msft_txt = msft['Text']
msft_txt[1]
# Out:
# 'Microsoft Cloud Strength Drives Third Quarter Results  REDMOND, Wash. \x97 April\xa024, 2019\n\x97 Microsoft Corp. today announced the following results for the quarter ended March\xa031, 2019, as compared to the corresponding period of last fiscal year: \n\xa0\n\n\n\xa0\n\x95\n\xa0\n Revenue was $30.6\xa0billion and increased 14% \n\n\n\xa0\n\x95\n\xa0\n Operating income was $10.3\xa0billion and increased 25% \n\n\n\xa0\n\x95\n\xa0\n Net income was $8.8\xa0billion and increased 19% \n\n\n\xa0\n\x95\n\xa0\n Diluted earnings per share was $1.14 and increased 20% \n\x93Leading organizations of every size in every industry trust the Microsoft cloud. We are accelerating our innovation across the cloud and\nedge so our customers can build the digital capability increasingly required to compete and grow,\x94 said Satya Nadella, CEO of Microsoft.  Microsoft returned $7.4\xa0billion to shareholders in the form of share repurchases and dividends in the third quarter of fiscal year 2019. \n\x
# ...

# %%
from textblob import TextBlob
